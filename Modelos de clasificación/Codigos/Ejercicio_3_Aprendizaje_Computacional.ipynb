# %%
## for data
import pandas as pd
import numpy as np

## for plotting
import matplotlib.pyplot as plt
import seaborn as sns

## for statistical tests
import scipy

## for machine learning
from sklearn import model_selection, preprocessing, feature_selection, ensemble, linear_model, metrics, decomposition
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, recall_score, precision_score
from sklearn.svm import SVC
from sklearn import datasets
import matplotlib.cm as cm

# %%
data = np.loadtxt('/content/misterious_data_1.txt')
#print(data[0])

# %%
n_features = 153
n_samples = 528

x = np.empty((n_samples, n_features)) #data o features
y = np.empty((n_samples,), dtype=int) #target

with open('/content/misterious_data_1.txt', 'r') as file:
    for i, line in enumerate(file):
        values = line.strip().split('\t')
        y[i] = int(values[0])
        features = [float(value) for value in values[1:]]
        x[i] = features

# %%
n_features = len(x)
n_targets = len(y)
targets = ['1', '2']

print (n_features)
print (n_targets)
# Out:
# 528
# 528

# %%
#Evaluación de modelos usando k-folds cross validation (k = 5)
n_folds = 5
kf = StratifiedKFold(n_splits=n_folds, shuffle = True)

# %%
# SVM con kernel lineal con 30% de las pruebas

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
clf = SVC(kernel = 'linear')
clf.fit(X_train, y_train)

acc = 0

cv_y_test = []
cv_y_pred = []

for train_index, test_index in kf.split(x, y):

        # Training phase
        x_train = x[train_index, :]
        y_train = y[train_index]

        clf_cv = SVC(kernel = 'linear')
        clf_cv.fit(x_train, y_train)

        # Test phase
        x_test = x[test_index, :]
        y_test = y[test_index]
        y_pred = clf_cv.predict(x_test)

        # Concatenate results of evaluation
        cv_y_test.append(y_test)
        cv_y_pred.append(y_pred)

        # Performance scores
        acc += accuracy_score(y_test, y_pred)

    # Model performance
print("Modelo SVM con kernel lineal:")
print("----------------------- K = 5 -----------------------")
print(classification_report(np.concatenate(cv_y_test), np.concatenate(cv_y_pred)))

    # Print average performance
acc = acc/n_folds
print('Exactitud del modelo: ', acc)
# Out:
# Modelo SVM con kernel lineal:
# ----------------------- K = 5 -----------------------
#               precision    recall  f1-score   support
#
#            1       0.79      0.77      0.78       264
#            2       0.77      0.80      0.79       264
#
#     accuracy                           0.78       528
#    macro avg       0.78      0.78      0.78       528
# weighted avg       0.78      0.78      0.78       528
#
# Exactitud del modelo:  0.7820664869721474

# %%
#Evaluación de modelos usando k-folds cross validation (k = 5)
n_folds = 5
kf = StratifiedKFold(n_splits=n_folds, shuffle = True)

# %%
# SVM con kernel lineal con 10% de las pruebas

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)
clf = SVC(kernel = 'linear')
clf.fit(X_train, y_train)

acc = 0

cv_y_test = []
cv_y_pred = []

for train_index, test_index in kf.split(x, y):

        # Training phase
        x_train = x[train_index, :]
        y_train = y[train_index]

        clf_cv = SVC(kernel = 'linear')
        clf_cv.fit(x_train, y_train)

        # Test phase
        x_test = x[test_index, :]
        y_test = y[test_index]
        y_pred = clf_cv.predict(x_test)

        # Concatenate results of evaluation
        cv_y_test.append(y_test)
        cv_y_pred.append(y_pred)

        # Performance scores
        acc += accuracy_score(y_test, y_pred)

    # Model performance
print("Modelo SVM con kernel lineal:")
print("------------------ test_size = 10% ------------------")
print("----------------------- K = 5 -----------------------")
print(classification_report(np.concatenate(cv_y_test), np.concatenate(cv_y_pred)))

    # Print average performance
acc = acc/n_folds
print('Exactitud del modelo: ', acc)
# Out:
# Modelo SVM con kernel lineal:
# ------------------ test_size = 10% ------------------
# ----------------------- K = 5 -----------------------
#               precision    recall  f1-score   support
#
#            1       0.78      0.78      0.78       264
#            2       0.78      0.78      0.78       264
#
#     accuracy                           0.78       528
#    macro avg       0.78      0.78      0.78       528
# weighted avg       0.78      0.78      0.78       528
#
# Exactitud del modelo:  0.7803593890386343

# %%
#Evaluación de modelos usando k-folds cross validation (k = 5)
n_folds = 5
kf = StratifiedKFold(n_splits=n_folds, shuffle = True)

# %%
# SVM con kernel lineal con 10%, 20%, 30% ... 95% de las pruebas
fin = 95;
n = 15 #Se inicializa desde 2 porque un número menor no es valido.

while n <= fin:

  X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=n, random_state=42)
  clf = SVC(kernel = 'linear')
  clf.fit(X_train, y_train)

  acc = 0

  cv_y_test = []
  cv_y_pred = []

  for train_index, test_index in kf.split(x, y):

        # Training phase
        x_train = x[train_index, :]
        y_train = y[train_index]

        clf_cv = SVC(kernel = 'linear')
        clf_cv.fit(x_train, y_train)

        # Test phase
        x_test = x[test_index, :]
        y_test = y[test_index]
        y_pred = clf_cv.predict(x_test)

        # Concatenate results of evaluation
        cv_y_test.append(y_test)
        cv_y_pred.append(y_pred)

        # Performance scores
        acc += accuracy_score(y_test, y_pred)

    # Model performance
  print("Modelo SVM con kernel lineal:")
  print('---------------------------test_size =', n,'%--------------------------')
  print(classification_report(np.concatenate(cv_y_test), np.concatenate(cv_y_pred)))

    # Print average performance
  acc = acc/n_folds
  print('Exactitud del modelo: ', acc)
  print()
  n = n + 5
# Out:
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 15 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.80      0.76      0.78       264
#            2       0.77      0.81      0.79       264
#
#     accuracy                           0.79       528
#    macro avg       0.79      0.79      0.79       528
# weighted avg       0.79      0.79      0.79       528
#
# Exactitud del modelo:  0.7858760107816712
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 20 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.77      0.77      0.77       264
#            2       0.77      0.78      0.77       264
#
#     accuracy                           0.77       528
#    macro avg       0.77      0.77      0.77       528
# weighted avg       0.77      0.77      0.77       528
#
# Exactitud del modelo:  0.7708355795148247
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 25 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.76      0.75      0.76       264
#            2       0.76      0.77      0.76       264
#
#     accuracy                           0.76       528
#    macro avg       0.76      0.76      0.76       528
# weighted avg       0.76      0.76      0.76       528
#
# Exactitud del modelo:  0.7594609164420485
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 30 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.79      0.81      0.80       264
#            2       0.81      0.78      0.79       264
#
#     accuracy                           0.80       528
#    macro avg       0.80      0.80      0.80       528
# weighted avg       0.80      0.80      0.80       528
#
# Exactitud del modelo:  0.7973584905660378
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 35 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.78      0.78      0.78       264
#            2       0.78      0.78      0.78       264
#
#     accuracy                           0.78       528
#    macro avg       0.78      0.78      0.78       528
# weighted avg       0.78      0.78      0.78       528
#
# Exactitud del modelo:  0.7784007187780773
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 40 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.78      0.79      0.78       264
#            2       0.79      0.78      0.78       264
#
#     accuracy                           0.78       528
#    macro avg       0.78      0.78      0.78       528
# weighted avg       0.78      0.78      0.78       528
#
# Exactitud del modelo:  0.7840790655884995
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 45 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.77      0.79      0.78       264
#            2       0.78      0.77      0.78       264
#
#     accuracy                           0.78       528
#    macro avg       0.78      0.78      0.78       528
# weighted avg       0.78      0.78      0.78       528
#
# Exactitud del modelo:  0.7783108715184187
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 50 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.78      0.80      0.79       264
#            2       0.79      0.77      0.78       264
#
#     accuracy                           0.78       528
#    macro avg       0.78      0.78      0.78       528
# weighted avg       0.78      0.78      0.78       528
#
# Exactitud del modelo:  0.7839353099730458
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 55 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.78      0.76      0.77       264
#            2       0.77      0.79      0.78       264
#
#     accuracy                           0.77       528
#    macro avg       0.77      0.77      0.77       528
# weighted avg       0.77      0.77      0.77       528
#
# Exactitud del modelo:  0.7747169811320754
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 60 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.77      0.76      0.77       264
#            2       0.76      0.78      0.77       264
#
#     accuracy                           0.77       528
#    macro avg       0.77      0.77      0.77       528
# weighted avg       0.77      0.77      0.77       528
#
# Exactitud del modelo:  0.7690026954177898
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 65 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.75      0.77      0.76       264
#            2       0.77      0.75      0.76       264
#
#     accuracy                           0.76       528
#    macro avg       0.76      0.76      0.76       528
# weighted avg       0.76      0.76      0.76       528
#
# Exactitud del modelo:  0.7595327942497754
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 70 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.78      0.78      0.78       264
#            2       0.78      0.78      0.78       264
#
#     accuracy                           0.78       528
#    macro avg       0.78      0.78      0.78       528
# weighted avg       0.78      0.78      0.78       528
#
# Exactitud del modelo:  0.7821383647798742
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 75 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.79      0.78      0.79       264
#            2       0.78      0.79      0.79       264
#
#     accuracy                           0.79       528
#    macro avg       0.79      0.79      0.79       528
# weighted avg       0.79      0.79      0.79       528
#
# Exactitud del modelo:  0.7860377358490566
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 80 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.77      0.77      0.77       264
#            2       0.77      0.77      0.77       264
#
#     accuracy                           0.77       528
#    macro avg       0.77      0.77      0.77       528
# weighted avg       0.77      0.77      0.77       528
#
# Exactitud del modelo:  0.7709074573225516
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 85 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.75      0.79      0.77       264
#            2       0.78      0.73      0.76       264
#
#     accuracy                           0.76       528
#    macro avg       0.76      0.76      0.76       528
# weighted avg       0.76      0.76      0.76       528
#
# Exactitud del modelo:  0.7633423180592993
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 90 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.79      0.77      0.78       264
#            2       0.77      0.80      0.79       264
#
#     accuracy                           0.78       528
#    macro avg       0.78      0.78      0.78       528
# weighted avg       0.78      0.78      0.78       528
#
# Exactitud del modelo:  0.7822102425876011
#
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 95 %--------------------------
#               precision    recall  f1-score   support
#
#            1       0.78      0.73      0.76       264
#            2       0.75      0.79      0.77       264
#
#     accuracy                           0.76       528
#    macro avg       0.76      0.76      0.76       528
# weighted avg       0.76      0.76      0.76       528
#
# Exactitud del modelo:  0.763288409703504

# %%
# SVM con kernel lineal con 95% de las pruebas
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.95, random_state=42)
clf = SVC(kernel = 'linear')
clf.fit(X_train, y_train)

acc = 0

cv_y_test = []
cv_y_pred = []

for train_index, test_index in kf.split(x, y):

    # Training phase
    x_train = x[train_index, :]
    y_train = y[train_index]

    clf_cv = SVC(kernel = 'linear')
    clf_cv.fit(x_train, y_train)

    # Test phase
    x_test = x[test_index, :]
    y_test = y[test_index]
    y_pred = clf_cv.predict(x_test)

    # Concatenate results of evaluation
    cv_y_test.append(y_test)
    cv_y_pred.append(y_pred)

    # Performance scores
    acc += accuracy_score(y_test, y_pred)

# Model performance
print("Modelo SVM con kernel lineal:")
print("---------------------------test_size = 95%--------------------------")
print(classification_report(np.concatenate(cv_y_test), np.concatenate(cv_y_pred)))

# Print average performance
acc = acc/n_folds
print('Exactitud del modelo: ', acc)
# Out:
# Modelo SVM con kernel lineal:
# ---------------------------test_size = 95%--------------------------
#               precision    recall  f1-score   support
#
#            1       0.78      0.78      0.78       264
#            2       0.78      0.78      0.78       264
#
#     accuracy                           0.78       528
#    macro avg       0.78      0.78      0.78       528
# weighted avg       0.78      0.78      0.78       528
#
# Exactitud del modelo:  0.7804851752021563
